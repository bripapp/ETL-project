# %%
import pandas as pd

# %%
blockbuster_csv = "Resources/blockbuster.csv"
blockbuster_df = pd.read_csv(blockbuster_csv, encoding='latin1')
blockbuster_df.head()
# Out:
#    release_year  rank_in_year  imdb_rating mpaa_rating  \
# 0          2019             1          8.5       PG-13
# 1          2019             2          7.0          PG
# 2          2019             3          7.2          PG
# 3          2019             4          7.6       PG-13
# 4          2019             5          6.9       PG-13
#
#                   film_title  film_budget  length_in_min domestic_distributor  \
# 0          Avengers: Endgame  356,000,000            181         Walt Disney
# 1              The Lion King  260,000,000            118         Walt Disney
# 2                  Frozen II  150,000,000            103         Walt Disney
# 3  Spider-Man: Far from Home  160,000,000            129        Sony Pictures
# 4             Captain Marvel  175,000,000            123         Walt Disney
#
#   worldwide_gross domestic_gross    genre_1    genre_2 genre_3
# 0   2,797,800,564    858,373,000     Action  Adventure   Drama
# ...

# %%
blockbusters_df = blockbuster_df.rename(columns={"release_year": "Release Year", 
                                                 "rank_in_year": "Rank in Year",
                                                 "imdb_rating": "IMDb Rating", 
                                                 "mpaa_rating": "MPAA Rating", 
                                                 "film_title": "Title",
                                                 "film_budget": "Film Budget", 
                                                 "length_in_min": "Runtime", 
                                                 "domestic_distributor": "Domestic Distributor",
                                                 "worldwide_gross": "Worldwide Gross", 
                                                 "domestic_gross": "Domestic Gross", 
                                                 "genre_1": "Genre 1",
                                                 "genre_2": "Genre 2", 
                                                 "genre_3": "Genre 3"})

# %%
blockbusters_df['Film Budget'].replace(',','', regex=True, inplace=True)
blockbusters_df['Worldwide Gross'].replace(',','', regex=True, inplace=True)
blockbusters_df['Domestic Gross'].replace(',','', regex=True, inplace=True)

# %%
blockbusters_df.head()
# Out:
#    Release Year  Rank in Year  IMDb Rating MPAA Rating  \
# 0          2019             1          8.5       PG-13
# 1          2019             2          7.0          PG
# 2          2019             3          7.2          PG
# 3          2019             4          7.6       PG-13
# 4          2019             5          6.9       PG-13
#
#                        Title Film Budget  Runtime Domestic Distributor  \
# 0          Avengers: Endgame   356000000      181         Walt Disney
# 1              The Lion King   260000000      118         Walt Disney
# 2                  Frozen II   150000000      103         Walt Disney
# 3  Spider-Man: Far from Home   160000000      129        Sony Pictures
# 4             Captain Marvel   175000000      123         Walt Disney
#
#   Worldwide Gross Domestic Gross    Genre 1    Genre 2 Genre 3
# 0      2797800564      858373000     Action  Adventure   Drama
# 1      1656943394      543638043  Animation  Adventure   Drama
# ...

# %%
# read out as csv
blockbusters_df.to_csv('blockbuster.csv')
