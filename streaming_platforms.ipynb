# %%
import pandas as pd

# %%
platforms_csv = "Resources/streaming_platforms.csv"
platforms_df = pd.read_csv(platforms_csv)
platforms_df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
# drop unnecessary columns
platforms_df.drop('Unnamed: 0', 1, inplace=True)
platforms_df.drop('Age', 1, inplace=True)
platforms_df.drop('Type', 1, inplace=True)
platforms_df.dropna(inplace=True)

# %%
# new dataframe to hold column separated values
directors_df = platforms_df["Directors"].str.split(",", n = -1, expand = True)

# add new columns to platforms_df
platforms_df['Director 1'] = directors_df[0]
platforms_df['Director 2'] = directors_df[1]

# drop old 'Directors' column
platforms_df.drop(columns = ['Directors'], inplace=True)
platforms_df.head()
# Out:
#    ID                           Title  Year  IMDb Rotten Tomatoes  Netflix  \
# 0   1                       Inception  2010   8.8             87%        1
# 1   2                      The Matrix  1999   8.7             87%        1
# 2   3          Avengers: Infinity War  2018   8.5             84%        1
# 3   4              Back to the Future  1985   8.5             96%        1
# 4   5  The Good, the Bad and the Ugly  1966   8.8             97%        1
#
#    Hulu  Prime Video  Disney+                            Genres  \
# 0     0            0        0  Action,Adventure,Sci-Fi,Thriller
# 1     0            0        0                     Action,Sci-Fi
# 2     0            0        0           Action,Adventure,Sci-Fi
# 3     0            0        0           Adventure,Comedy,Sci-Fi
# 4     0            1        0                           Western
#
#                         Country                 Language  Runtime  \
# ...

# %%
# new dataframe to hold comma separated columns
country_df = platforms_df['Country'].str.split(',', n = -1, expand = True)

# add new columns to platforms_df (only taking first 2)
platforms_df['Country 1'] = country_df[0]
platforms_df['Country 2'] = country_df[1]

# drop old 'Country' column
platforms_df.drop(columns = ['Country'], inplace=True)
platforms_df.head()
# Out:
#    ID                           Title  Year  IMDb Rotten Tomatoes  Netflix  \
# 0   1                       Inception  2010   8.8             87%        1
# 1   2                      The Matrix  1999   8.7             87%        1
# 2   3          Avengers: Infinity War  2018   8.5             84%        1
# 3   4              Back to the Future  1985   8.5             96%        1
# 4   5  The Good, the Bad and the Ugly  1966   8.8             97%        1
#
#    Hulu  Prime Video  Disney+                            Genres  \
# 0     0            0        0  Action,Adventure,Sci-Fi,Thriller
# 1     0            0        0                     Action,Sci-Fi
# 2     0            0        0           Action,Adventure,Sci-Fi
# 3     0            0        0           Adventure,Comedy,Sci-Fi
# 4     0            1        0                           Western
#
#                   Language  Runtime         Director 1       Director 2  \
# ...

# %%
# new dataframe to hold comma separated columns
genres_df = platforms_df['Genres'].str.split(',', n = -1, expand = True)

# add new columns to platforms_df (only taking first 3)
platforms_df['Genres 1'] = genres_df[0]
platforms_df['Genres 2'] = genres_df[1]
platforms_df['Genres 3'] = genres_df[2]

# drop old 'Genres' column
platforms_df.drop(columns = ['Genres'], inplace=True)
platforms_df.head()
# Out:
#    ID                           Title  Year  IMDb Rotten Tomatoes  Netflix  \
# 0   1                       Inception  2010   8.8             87%        1
# 1   2                      The Matrix  1999   8.7             87%        1
# 2   3          Avengers: Infinity War  2018   8.5             84%        1
# 3   4              Back to the Future  1985   8.5             96%        1
# 4   5  The Good, the Bad and the Ugly  1966   8.8             97%        1
#
#    Hulu  Prime Video  Disney+                 Language  Runtime  \
# 0     0            0        0  English,Japanese,French    148.0
# 1     0            0        0                  English    136.0
# 2     0            0        0                  English    149.0
# 3     0            0        0                  English    116.0
# 4     0            1        0                  Italian    161.0
#
#           Director 1       Director 2      Country 1       Country 2  \
# ...

# %%
# new dataframe to hold comma separated columns
language_df = platforms_df['Language'].str.split(',', n = -1, expand = True)

# add new columns to platforms_df (only taking first 2)
platforms_df['Language 1'] = language_df[0]
platforms_df['Language 2'] = language_df[1]

# drop old 'Language' column
platforms_df.drop(columns = ['Language'], inplace=True)
platforms_df.head()
# Out:
#           ID                           Title  Year  IMDb Rotten Tomatoes  \
# 0          1                       Inception  2010   8.8             87%
# 1          2                      The Matrix  1999   8.7             87%
# 2          3          Avengers: Infinity War  2018   8.5             84%
# 3          4              Back to the Future  1985   8.5             96%
# 4          5  The Good, the Bad and the Ugly  1966   8.8             97%
# ...      ...                             ...   ...   ...             ...
# 16671  16672          George of the Jungle 2  2003   3.3             17%
# 16677  16678                   That Darn Cat  1997   4.7             13%
# 16687  16688                          Kazaam  1996   3.0              6%
# 16705  16706                Meet the Deedles  1998   4.1              7%
# 16719  16720                      Pocahontas  1995   5.3             55%
#
#        Netflix  Hulu  Prime Video  Disney+                 Language  Runtime  \
# ...

# %%
blockbuster_csv = "Resources/blockbuster.csv"
blockbuster_df = pd.read_csv(blockbuster_csv, encoding='latin1')
blockbuster_df.head()

# %%
blockbuster_df.drop('Unnamed: 0', 1, inplace=True)
